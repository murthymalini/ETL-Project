# %% [markdown]
# # BTC Cleanup

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create a reference the CSV file desired
csv_path = "Resources/btc.csv"

# Read the CSV into a Pandas DataFrame
btc_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
btc_df.head()
# Out:
#      date  txvolume_usd  adjustedtxvolume_usd  txcount  marketcap_usd  \
# 0  1/3/09           NaN                   NaN      NaN            NaN
# 1  1/4/09           NaN                   NaN      NaN            NaN
# 2  1/5/09           NaN                   NaN      NaN            NaN
# 3  1/6/09           NaN                   NaN      NaN            NaN
# 4  1/7/09           NaN                   NaN      NaN            NaN
#
#    price_usd  exchangevolume_usd  realizedcap_usd  generatedcoins  fees  \
# 0        NaN                 NaN              0.0             NaN   NaN
# 1        NaN                 NaN              0.0             NaN   NaN
# 2        NaN                 NaN              0.0             NaN   NaN
# 3        NaN                 NaN              0.0             NaN   NaN
# 4        NaN                 NaN              0.0             NaN   NaN
#
#    activeaddresses  averagedifficulty  paymentcount  mediantxvalue_usd  \
# ...

# %%
# Drop NaN Values
clean_btc_df = btc_df.dropna(how="any")
clean_btc_df.head()
# Out:
#          date  txvolume_usd  adjustedtxvolume_usd  txcount  marketcap_usd  \
# 1576  4/28/13  6.879868e+07           31537136.80  41702.0   1.500656e+09
# 1577  4/29/13  1.138128e+08           48216524.64  51602.0   1.491703e+09
# 1578  4/30/13  8.426632e+07           56867903.11  47450.0   1.598310e+09
# 1579   5/1/13  1.206825e+08           82087357.75  55176.0   1.543334e+09
# 1580   5/2/13  9.337533e+07           58237355.01  55295.0   1.292577e+09
#
#       price_usd  exchangevolume_usd  realizedcap_usd  generatedcoins  \
# 1576     135.30                 0.0      503515007.4       4425.0000
# 1577     134.44                 0.0      511015444.9       4349.9988
# 1578     144.00                 0.0      514278507.5       3725.0000
# 1579     139.00                 0.0      511047380.3       3775.0000
# 1580     116.38                 0.0      508395558.4       3350.0000
#
#            fees  activeaddresses  averagedifficulty  paymentcount  \
# ...

# %%
# reset index
clean_btc_df.reset_index()
# Out:
#       index     date  txvolume_usd  adjustedtxvolume_usd   txcount  \
# 0      1576  4/28/13  6.879868e+07          3.153714e+07   41702.0
# 1      1577  4/29/13  1.138128e+08          4.821652e+07   51602.0
# 2      1578  4/30/13  8.426632e+07          5.686790e+07   47450.0
# 3      1579   5/1/13  1.206825e+08          8.208736e+07   55176.0
# 4      1580   5/2/13  9.337533e+07          5.823736e+07   55295.0
# 5      1581   5/3/13  7.273133e+07          5.465641e+07   51275.0
# 6      1582   5/4/13  3.896570e+07          2.319290e+07   50102.0
# 7      1583   5/5/13  5.708371e+07          2.555227e+07   50167.0
# 8      1584   5/6/13  8.567133e+07          3.666392e+07   53174.0
# 9      1585   5/7/13  9.672451e+07          3.794202e+07   56567.0
# 10     1586   5/8/13  7.989088e+07          3.932821e+07   50274.0
# 11     1587   5/9/13  6.453970e+07          4.047014e+07   66610.0
# 12     1588  5/10/13  7.883246e+07          4.303642e+07   67709.0
# ...

# %%
# export to csv 
clean_btc_df.to_csv("Output/clean_btc_df.csv")

# %%
# Filter the data so that only date for the last 2 years are in a DataFrame
clean_btc_df = clean_btc_df.drop(clean_btc_df.index[0:1525])

# %%
# select only rows needed for analysis
organized_btc_df = clean_btc_df[["date", "marketcap_usd", "price_usd"]]
organized_btc_df.head()
# Out:
#         date  marketcap_usd  price_usd
# 3101  7/1/17   4.093335e+10    2492.60
# 3102  7/2/17   4.001616e+10    2436.40
# 3103  7/3/17   4.104228e+10    2498.56
# 3104  7/4/17   4.207297e+10    2561.00
# 3105  7/5/17   4.276554e+10    2602.87

# %%
# add number of coins column
organized_btc_number = organized_btc_df['marketcap_usd'].div(organized_btc_df['price_usd'])
organized_btc_df['number_of_coins'] = organized_btc_number
organized_btc_df.head()
# Out:
# /Users/melissamason/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         date  marketcap_usd  price_usd  number_of_coins
# 3101  7/1/17   4.093335e+10    2492.60     1.642195e+07
# 3102  7/2/17   4.001616e+10    2436.40     1.642430e+07
# 3103  7/3/17   4.104228e+10    2498.56     1.642638e+07
# 3104  7/4/17   4.207297e+10    2561.00     1.642834e+07
# 3105  7/5/17   4.276554e+10    2602.87     1.643015e+07

# %%
# Rename headers
organized_btc_df = organized_btc_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_btc_df.head()
# Out:
#         Date  Market Cap (USD)  Price (USD)  Number of Coins
# 3101  7/1/17      4.093335e+10      2492.60     1.642195e+07
# 3102  7/2/17      4.001616e+10      2436.40     1.642430e+07
# 3103  7/3/17      4.104228e+10      2498.56     1.642638e+07
# 3104  7/4/17      4.207297e+10      2561.00     1.642834e+07
# 3105  7/5/17      4.276554e+10      2602.87     1.643015e+07

# %%
count = organized_btc_df["Date"].count()
print(count)
# Out:
# 743

# %%
organized_btc_df.to_csv("Output/organized_btc_df.csv")

# %%
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# # ETH Cleanup

# %%
# Create a reference the CSV file desired
csv_path = "Resources/eth.csv"

# Read the CSV into a Pandas DataFrame
eth_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
eth_df.head()
# Out:
#       date  txvolume_usd  adjustedtxvolume_usd  txcount  marketcap_usd  \
# 0  7/30/15           NaN                   NaN      NaN            NaN
# 1  7/31/15           NaN                   NaN      NaN            NaN
# 2   8/1/15           NaN                   NaN      NaN            NaN
# 3   8/2/15           NaN                   NaN      NaN            NaN
# 4   8/3/15           NaN                   NaN      NaN            NaN
#
#    price_usd  exchangevolume_usd  generatedcoins  fees  activeaddresses  \
# 0        NaN                 NaN     39311.09375   NaN              NaN
# 1        NaN                 NaN     36191.71875   NaN              NaN
# 2        NaN                 NaN     27702.18750   NaN              NaN
# 3        NaN                 NaN     28227.18750   NaN              NaN
# 4        NaN                 NaN     27976.71875   NaN              NaN
#
#    mediantxvalue_usd  medianfee  averagedifficulty  paymentcount  blocksize  \
# ...

# %%
# Drap NaN values
clean_eth_df = eth_df.dropna(how="any")

# %%
# reset index
clean_eth_df.reset_index()
# Out:
#       index     date  txvolume_usd  adjustedtxvolume_usd    txcount  \
# 0         8   8/7/15  5.684487e+06          5.684487e+06     2050.0
# 1         9   8/8/15  3.789968e+07          3.789968e+07     2881.0
# 2        10   8/9/15  8.236055e+05          8.236055e+05     1329.0
# 3        11  8/10/15  1.194050e+06          1.194050e+06     2037.0
# 4        12  8/11/15  1.053130e+06          1.053130e+06     4963.0
# 5        13  8/12/15  7.974742e+05          7.974742e+05     2036.0
# 6        14  8/13/15  2.182920e+06          2.182920e+06     2842.0
# 7        15  8/14/15  4.162002e+06          4.162002e+06     3174.0
# 8        16  8/15/15  1.390241e+07          1.390241e+07     2284.0
# 9        17  8/16/15  2.898480e+06          2.898480e+06     2440.0
# 10       18  8/17/15  5.383055e+06          5.383055e+06     2512.0
# 11       19  8/18/15  2.409106e+06          2.409106e+06     2494.0
# 12       20  8/19/15  1.691424e+06          1.691424e+06     3246.0
# ...

# %%
# export to csv 
clean_eth_df.to_csv("clean_eth_df.csv")

# %%
# Filter the data so that only date for the last 2 years are in a DataFrame
clean_eth_df = clean_eth_df.drop(clean_eth_df.index[0:694])

# %%
# select only rows needed for analysis
organized_eth_df = clean_eth_df[["date", "marketcap_usd", "price_usd"]]
organized_eth_df.head()
# Out:
#        date  marketcap_usd  price_usd
# 702  7/1/17   2.726714e+10     293.35
# 703  7/2/17   2.557964e+10     275.12
# 704  7/3/17   2.682321e+10     288.41
# 705  7/4/17   2.625292e+10     282.19
# 706  7/5/17   2.541466e+10     273.10

# %%
# add number of coins column
organized_eth_number = organized_eth_df['marketcap_usd'].div(organized_eth_df['price_usd'])
organized_eth_df['number_of_coins'] = organized_eth_number
organized_eth_df.head()
# Out:
# /Users/melissamason/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        date  marketcap_usd  price_usd  number_of_coins
# 702  7/1/17   2.726714e+10     293.35     9.295089e+07
# 703  7/2/17   2.557964e+10     275.12     9.297630e+07
# 704  7/3/17   2.682321e+10     288.41     9.300375e+07
# 705  7/4/17   2.625292e+10     282.19     9.303279e+07
# 706  7/5/17   2.541466e+10     273.10     9.305990e+07

# %%
# Rename headers
organized_eth_df = organized_eth_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_eth_df.head()
# Out:
#        Date  Market Cap (USD)  Price (USD)  Number of Coins
# 702  7/1/17      2.726714e+10       293.35     9.295089e+07
# 703  7/2/17      2.557964e+10       275.12     9.297630e+07
# 704  7/3/17      2.682321e+10       288.41     9.300375e+07
# 705  7/4/17      2.625292e+10       282.19     9.303279e+07
# 706  7/5/17      2.541466e+10       273.10     9.305990e+07

# %%
count = organized_eth_df["Date"].count()
print(count)
# Out:
# 742

# %%
organized_eth_df.to_csv("Output/organized_eth_df.csv")

# %% [markdown]
# # LTC Cleanup

# %%
# Create a reference the CSV file desired
csv_path_4 = "Resources/ltc.csv"

# Read the CSV into a Pandas DataFrame
ltc_df = pd.read_csv(csv_path_4)

# Print the first five rows of data to the screen
ltc_df.head()
# Out:
#        date  txvolume_usd  adjustedtxvolume_usd  txcount  marketcap_usd  \
# 0   10/7/11           NaN                   NaN      NaN            NaN
# 1   10/8/11           NaN                   NaN      0.0            NaN
# 2   10/9/11           NaN                   NaN      0.0            NaN
# 3  10/10/11           NaN                   NaN      0.0            NaN
# 4  10/11/11           NaN                   NaN      0.0            NaN
#
#    price_usd  exchangevolume_usd  realizedcap_usd  generatedcoins  fees  \
# 0        NaN                 NaN              0.0             NaN   NaN
# 1        NaN                 NaN              0.0            50.0   0.0
# 2        NaN                 NaN              0.0             NaN   0.0
# 3        NaN                 NaN              0.0             NaN   0.0
# 4        NaN                 NaN              0.0             NaN   0.0
#
#    activeaddresses  averagedifficulty  paymentcount  mediantxvalue_usd  \
# ...

# %%
# Drap NaN values
clean_ltc_df = ltc_df.dropna(how="any")

# %%
# reset index
clean_ltc_df.reset_index()
# Out:
#       index     date  txvolume_usd  adjustedtxvolume_usd  txcount  \
# 0       569  4/28/13  4.431952e+07          2.556844e+06   9174.0
# 1       570  4/29/13  3.647810e+07          2.111820e+06   9275.0
# 2       571  4/30/13  4.039166e+07          1.969543e+06   9099.0
# 3       572   5/1/13  7.637420e+07          4.691922e+06   8990.0
# 4       573   5/2/13  1.163151e+07          2.501720e+06   8031.0
# 5       574   5/3/13  4.632241e+06          1.964664e+06   6280.0
# 6       575   5/4/13  5.725030e+06          1.648315e+06   6168.0
# 7       576   5/5/13  6.579465e+06          3.060323e+06   5948.0
# 8       577   5/6/13  1.348974e+07          4.020198e+06  10636.0
# 9       578   5/7/13  9.082298e+06          2.615556e+06   8712.0
# 10      579   5/8/13  6.748147e+06          1.250363e+06   9035.0
# 11      580   5/9/13  9.291191e+06          1.487344e+06  12776.0
# 12      581  5/10/13  8.136962e+06          1.538562e+06  10503.0
# ...

# %%
# export to csv 
clean_ltc_df.to_csv("clean_ltc_df.csv")

# %%
# Filter the data so that only date for the last 2 years are in a DataFrame
clean_ltc_df = clean_ltc_df.drop(clean_ltc_df.index[0:1525])

# %%
# select only rows needed for analysis
organized_ltc_df = clean_ltc_df[["date", "marketcap_usd", "price_usd"]]
organized_ltc_df.head()
# Out:
#         date  marketcap_usd  price_usd
# 2094  7/1/17   2.092624e+09      40.40
# 2095  7/2/17   2.018032e+09      38.95
# 2096  7/3/17   2.149611e+09      41.48
# 2097  7/4/17   2.414012e+09      46.56
# 2098  7/5/17   2.866509e+09      55.27

# %%
# add number of coins column
organized_ltc_number = organized_ltc_df['marketcap_usd'].div(organized_ltc_df['price_usd'])
organized_ltc_df['number_of_coins'] = organized_ltc_number
organized_ltc_df.head()
# Out:
# /Users/melissamason/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         date  marketcap_usd  price_usd  number_of_coins
# 2094  7/1/17   2.092624e+09      40.40     5.179762e+07
# 2095  7/2/17   2.018032e+09      38.95     5.181084e+07
# 2096  7/3/17   2.149611e+09      41.48     5.182282e+07
# 2097  7/4/17   2.414012e+09      46.56     5.184733e+07
# 2098  7/5/17   2.866509e+09      55.27     5.186374e+07

# %%
# Rename headers
organized_ltc_df = organized_ltc_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_ltc_df.head()
# Out:
#         Date  Market Cap (USD)  Price (USD)  Number of Coins
# 2094  7/1/17      2.092624e+09        40.40     5.179762e+07
# 2095  7/2/17      2.018032e+09        38.95     5.181084e+07
# 2096  7/3/17      2.149611e+09        41.48     5.182282e+07
# 2097  7/4/17      2.414012e+09        46.56     5.184733e+07
# 2098  7/5/17      2.866509e+09        55.27     5.186374e+07

# %%
count = organized_ltc_df["Date"].count()
print(count)
# Out:
# 743

# %%
organized_ltc_df.to_csv("Output/organized_ltc_df.csv")

# %% [markdown]
# # TRX Cleanup

# %%
# Create a reference the CSV file desired
csv_path_5 = "Resources/trx.csv"

# Read the CSV into a Pandas DataFrame
trx_df = pd.read_csv(csv_path_5)

# Print the first five rows of data to the screen
trx_df.head()
# Out:
#       date  txvolume_usd  txcount  paymentcount  activeaddresses  \
# 0  8/28/17           NaN        1             1                2
# 1  8/29/17           NaN        2             2                3
# 2  8/30/17           NaN        2             2                3
# 3  8/31/17           NaN        3             3                4
# 4   9/1/17           NaN       26            26               17
#
#    mediantxvalue_usd  marketcap_usd  price_usd  exchangevolume_usd
# 0                NaN            NaN        NaN                 NaN
# 1                NaN            NaN        NaN                 NaN
# 2                NaN            NaN        NaN                 NaN
# 3                NaN            NaN        NaN                 NaN
# 4                NaN            NaN        NaN                 NaN

# %%
# Drap NaN values
clean_trx_df = trx_df.dropna(how="any")

# %%
# reset index
clean_trx_df.reset_index()
# Out:
#      index      date  txvolume_usd  txcount  paymentcount  activeaddresses  \
# 0       16   9/13/17  1.904726e+06      384           384              391
# 1       17   9/14/17  2.678159e+06      334           334              283
# 2       18   9/15/17  3.372969e+05      169           169              176
# 3       19   9/16/17  2.497398e+05      204           204              151
# 4       20   9/17/17  2.693821e+05      258           258              187
# 5       21   9/18/17  1.968324e+06      463           463              383
# 6       22   9/19/17  1.784011e+06      377           377              303
# 7       23   9/20/17  4.727022e+05      310           310              264
# 8       24   9/21/17  6.675294e+05      363           363              252
# 9       25   9/22/17  2.124184e+05     1801          1801             1776
# 10      26   9/23/17  1.958852e+07     5616          5616             4172
# ...

# %%
# export to csv 
clean_trx_df.to_csv("clean_trx_df.csv")

# %%
# select only rows needed for analysis
organized_trx_df = clean_trx_df[["date", "marketcap_usd", "price_usd"]]
organized_trx_df.head()
# Out:
#        date  marketcap_usd  price_usd
# 16  9/13/17            0.0   0.002051
# 17  9/14/17            0.0   0.002006
# 18  9/15/17            0.0   0.001419
# 19  9/16/17            0.0   0.001815
# 20  9/17/17            0.0   0.001836

# %%
# add number of coins column
organized_trx_number = organized_trx_df['marketcap_usd'].div(organized_trx_df['price_usd'])
organized_trx_df['number_of_coins'] = organized_trx_number
organized_trx_df.head()
# Out:
# /Users/melissamason/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        date  marketcap_usd  price_usd  number_of_coins
# 16  9/13/17            0.0   0.002051              0.0
# 17  9/14/17            0.0   0.002006              0.0
# 18  9/15/17            0.0   0.001419              0.0
# 19  9/16/17            0.0   0.001815              0.0
# 20  9/17/17            0.0   0.001836              0.0

# %%
# Rename headers
organized_trx_df = organized_trx_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_trx_df.head()
# Out:
#        Date  Market Cap (USD)  Price (USD)  Number of Coins
# 16  9/13/17               0.0     0.002051              0.0
# 17  9/14/17               0.0     0.002006              0.0
# 18  9/15/17               0.0     0.001419              0.0
# 19  9/16/17               0.0     0.001815              0.0
# 20  9/17/17               0.0     0.001836              0.0

# %%
count = organized_trx_df["Date"].count()
print(count)
# Out:
# 668

# %%
organized_trx_df.to_csv("Output/organized_trx_df.csv")
