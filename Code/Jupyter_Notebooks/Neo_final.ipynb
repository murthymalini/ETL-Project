# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_path = "neo.csv"
neo_df = pd.read_csv(csv_path)
neo_df.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMrktCurUSD  \
# 0  2016-07-15          1       1          401            401.0            NaN
# 1  2016-07-16          0       0            0              NaN            NaN
# 2  2016-07-17          0       0            0              NaN            NaN
# 3  2016-07-18          0       0            0              NaN            NaN
# 4  2016-07-19          0       0            0              NaN            NaN
#
#    FeeMeanUSD  FeeMedUSD  FeeTotUSD  IssContNtv  ...  TxTfrValAdjUSD  \
# 0         NaN        NaN        NaN           0  ...             NaN
# 1         NaN        NaN        NaN           0  ...             NaN
# 2         NaN        NaN        NaN           0  ...             NaN
# 3         NaN        NaN        NaN           0  ...             NaN
# 4         NaN        NaN        NaN           0  ...             NaN
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# ...

# %%
clean_neo_df = neo_df.dropna(how="any")
clean_neo_df.head()
# Out:
#            date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  \
# 730  2018-07-15       4599    4021      9313023      2316.096245
# 731  2018-07-16       5738    4087     12947523      3167.977245
# 732  2018-07-17       8568    3947     28550662      7233.509501
# 733  2018-07-18       6705    4071     21907019      5381.237779
# 734  2018-07-19       5244    4000     14280528      3570.132000
#
#      CapMrktCurUSD  FeeMeanUSD  FeeMedUSD    FeeTotUSD  IssContNtv  ...  \
# 730   3.348216e+09    0.000055        0.0     1.319079           0  ...
# 731   3.684568e+09    0.163637        0.0  5851.676872           0  ...
# 732   3.929847e+09    0.000006        0.0     0.576344           0  ...
# 733   3.761783e+09    0.000260        0.0    18.752287           0  ...
# 734   3.588916e+09    0.000066        0.0     2.684663           0  ...
#
#      TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# ...

# %%
clean_neo_df.reset_index()
# Out:
#      index        date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  \
# 0      730  2018-07-15       4599    4021      9313023      2316.096245
# 1      731  2018-07-16       5738    4087     12947523      3167.977245
# 2      732  2018-07-17       8568    3947     28550662      7233.509501
# 3      733  2018-07-18       6705    4071     21907019      5381.237779
# 4      734  2018-07-19       5244    4000     14280528      3570.132000
# ..     ...         ...        ...     ...          ...              ...
# 473   1203  2019-10-31       1984    5199      8510902      1637.026736
# 474   1204  2019-11-01       1835    5107      7010312      1372.686900
# 475   1205  2019-11-02       2043    5120      7035837      1374.186914
# 476   1206  2019-11-03       1825    5117      7249299      1416.708814
# 477   1207  2019-11-04       2316    5146      8884653      1726.516323
#
#      CapMrktCurUSD  FeeMeanUSD  FeeMedUSD    FeeTotUSD  ...  TxTfrValAdjUSD  \
# ...

# %%
# export to csv 
clean_neo_df.to_csv("clean_neo_df.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-5ad90bb8fb53> in <module>
#       1 # export to csv
# ----> 2 clean_neo_df.to_csv("clean_neo_df.csv")
#
# ~\Anaconda3\envs\pyData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\envs\pyData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
clean_neo_df = clean_neo_df.drop(clean_neo_df.index[384:479])

# %%
organized_neo_df = clean_neo_df[["date", "CapMrktCurUSD", "PriceUSD"]]
organized_neo_df.head()
# Out:
#            date  CapMrktCurUSD   PriceUSD
# 730  2018-07-15   3.348216e+09  33.482163
# 731  2018-07-16   3.684568e+09  36.845677
# 732  2018-07-17   3.929847e+09  39.298473
# 733  2018-07-18   3.761783e+09  37.617829
# 734  2018-07-19   3.588916e+09  35.889156

# %%
organized_neo_number = organized_neo_df['CapMrktCurUSD'].div(organized_neo_df['PriceUSD'])
organized_neo_df['number_of_coins'] = organized_neo_number
organized_neo_df.head()
# Out:
# C:\Users\murth\Anaconda3\envs\pyData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            date  CapMrktCurUSD   PriceUSD  number_of_coins
# 730  2018-07-15   3.348216e+09  33.482163      100000000.0
# 731  2018-07-16   3.684568e+09  36.845677      100000000.0
# 732  2018-07-17   3.929847e+09  39.298473      100000000.0
# 733  2018-07-18   3.761783e+09  37.617829      100000000.0
# 734  2018-07-19   3.588916e+09  35.889156      100000000.0

# %%
organized_neo_df = organized_neo_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_neo_df.head()
# Out:
#            Date  CapMrktCurUSD   PriceUSD  Number of Coins
# 730  2018-07-15   3.348216e+09  33.482163      100000000.0
# 731  2018-07-16   3.684568e+09  36.845677      100000000.0
# 732  2018-07-17   3.929847e+09  39.298473      100000000.0
# 733  2018-07-18   3.761783e+09  37.617829      100000000.0
# 734  2018-07-19   3.588916e+09  35.889156      100000000.0

# %%
count = organized_neo_df["Date"].count()
print(count)
# Out:
# 384

# %%
organized_neo_df.to_csv("organized_neo_df.csv")

# %%
connection_string = "postgres:postgres@localhost:5432/test_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\pyData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\pyData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\envs\pyData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\envs\pyData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...
