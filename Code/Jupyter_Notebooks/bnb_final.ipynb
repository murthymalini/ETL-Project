# %%
import pandas as pd

# %%
csv_path = "bnb_mainnet.csv"
bnb_df = pd.read_csv(csv_path)
bnb_df.head()
# Out:
#          date  AdrActCnt  BlkCnt  CapMrktCurUSD  FeeMeanNtv  FeeMeanUSD  \
# 0  2019-04-18         18  165864   4.393535e+09    0.000625    0.013730
# 1  2019-04-19         29  218479   4.865168e+09    0.000625    0.015204
# 2  2019-04-20          9  219207   4.986854e+09    0.000625    0.015584
# 3  2019-04-21         12  219685   4.839555e+09    0.000625    0.015124
# 4  2019-04-22         36  219413   4.776442e+09    0.000625    0.014926
#
#    FeeMedNtv  FeeMedUSD  FeeTotNtv  FeeTotUSD  ...  TxTfrValAdjUSD  \
# 0   0.000625   0.013730   0.006250   0.137298  ...    2.337470e+03
# 1   0.000625   0.015204   0.017500   0.425702  ...    2.416425e+02
# 2   0.000625   0.015584   0.004375   0.109087  ...    5.236408e+04
# 3   0.000625   0.015124   0.007500   0.181483  ...    1.575275e+00
# 4   0.000625   0.014926   0.036875   0.880657  ...    1.194132e+07
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# ...

# %%
# clean_bnb_df = bnb_df.dropna(how="any")
# clean_bnb_df.head()

# %%
# bnb_df.describe

# %%
# clean_bnb_df.reset_index()

# %%
# # export to csv 
# clean_bnb_df.to_csv("clean_bnb_df.csv")

# %%
bnb_df = bnb_df.drop(bnb_df.index[107:202])

# %%
organized_bnb_df = bnb_df[["date", "CapMrktCurUSD", "PriceUSD"]]
organized_bnb_df.head()
# Out:
#          date  CapMrktCurUSD   PriceUSD
# 0  2019-04-18   4.393535e+09  21.967673
# 1  2019-04-19   4.865168e+09  24.325842
# 2  2019-04-20   4.986854e+09  24.934271
# 3  2019-04-21   4.839555e+09  24.197776
# 4  2019-04-22   4.776442e+09  23.882212

# %%
organized_bnb_number = organized_bnb_df['CapMrktCurUSD'].div(organized_bnb_df['PriceUSD'])
organized_bnb_df['number_of_coins']= organized_bnb_number
organized_bnb_df.head()
# Out:
# C:\Users\murth\Anaconda3\envs\pyData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          date  CapMrktCurUSD   PriceUSD  number_of_coins
# 0  2019-04-18   4.393535e+09  21.967673      200000000.0
# 1  2019-04-19   4.865168e+09  24.325842      200000000.0
# 2  2019-04-20   4.986854e+09  24.934271      200000000.0
# 3  2019-04-21   4.839555e+09  24.197776      200000000.0
# 4  2019-04-22   4.776442e+09  23.882212      200000000.0

# %%
organized_bnb_df = organized_bnb_df.rename(
    columns={"date": "Date", "marketcap_usd": "Market Cap (USD)", "price_usd": "Price (USD)", "number_of_coins": "Number of Coins"})
organized_bnb_df.head()
# Out:
#          Date  CapMrktCurUSD   PriceUSD  Number of Coins
# 0  2019-04-18   4.393535e+09  21.967673      200000000.0
# 1  2019-04-19   4.865168e+09  24.325842      200000000.0
# 2  2019-04-20   4.986854e+09  24.934271      200000000.0
# 3  2019-04-21   4.839555e+09  24.197776      200000000.0
# 4  2019-04-22   4.776442e+09  23.882212      200000000.0

# %%
count = organized_bnb_df["Date"].count()
print(count)
# Out:
# 107

# %%
organized_bnb_df.to_csv("organized_bnb_df.csv")
