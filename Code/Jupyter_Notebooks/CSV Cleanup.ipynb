# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Create a reference the CSV file desired
csv_path = "crd.csv"

# Read the CSV into a Pandas DataFrame
crd_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
crd_df.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMrktCurUSD  \
# 0  2016-07-24      14910    9388      9484872      1010.318705            NaN
# 1  2016-07-25      12384    5648      6990037      1237.612783   5.013648e+07
# 2  2016-07-26      16696    7750      9372983      1209.417161   2.100841e+08
# 3  2016-07-27      19134    5721      8353485      1460.144206   1.334783e+08
# 4  2016-07-28      11646    5957      6867164      1152.788988   1.423718e+08
#
#        DiffMean  FeeMeanNtv  FeeMeanUSD  FeeMedNtv  ...  TxTfrValAdjUSD  \
# 0  1.425784e+12    0.000779         NaN   0.000481  ...             NaN
# 1  3.263197e+12    0.000907    0.000553   0.000482  ...    3.519595e+06
# 2  4.324493e+12    0.000833    0.002124   0.000487  ...    1.857095e+07
# 3  8.546119e+12    0.000788    0.001276   0.000475  ...    1.351068e+07
# 4  6.348056e+12    0.000926    0.001600   0.000509  ...    2.016661e+07
#
# ...

# %%
# reset index
crd_df.reset_index()
# Out:
#       index        date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  \
# 0         0  2016-07-24      14910    9388      9484872      1010.318705
# 1         1  2016-07-25      12384    5648      6990037      1237.612783
# 2         2  2016-07-26      16696    7750      9372983      1209.417161
# 3         3  2016-07-27      19134    5721      8353485      1460.144206
# 4         4  2016-07-28      11646    5957      6867164      1152.788988
# ...     ...         ...        ...     ...          ...              ...
# 1194   1194  2019-10-31     436724    6596     10183972      1543.961795
# 1195   1195  2019-11-01     463640    6657     10232466      1537.098693
# 1196   1196  2019-11-02     480938    6623     10109872      1526.479239
# 1197   1197  2019-11-03     487123    6626     10060597      1518.351494
# 1198   1198  2019-11-04     456285    6492     10046189      1547.472120
#
#       CapMrktCurUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  ...  \
# ...

# %%
# export to csv 
crd_df.to_csv("clean_crd_df.csv")

# %%
# Filter the data so that only date for the last 2 years are in a DataFrame
clean_crd_df = crd_df.drop(crd_df.index[0:342])

# %%
# select only rows needed for analysis
clean_crd_df = clean_crd_df[["date", "CapMrktCurUSD", "PriceUSD"]]
clean_crd_df.head()
# Out:
#            date  CapMrktCurUSD   PriceUSD
# 342  2017-07-01   1.544252e+09  16.542040
# 343  2017-07-02   1.628663e+09  17.440446
# 344  2017-07-03   1.611146e+09  17.247060
# 345  2017-07-04   1.629516e+09  17.437723
# 346  2017-07-05   1.625689e+09  17.390919

# %%
# add number of coins column
organized_crd_number = clean_crd_df['CapMrktCurUSD'].div(clean_crd_df['PriceUSD'])
clean_crd_df['number_of_coins'] = organized_crd_number
clean_crd_df.head()
# Out:
#            date  CapMrktCurUSD   PriceUSD  number_of_coins
# 342  2017-07-01   1.544252e+09  16.542040     9.335318e+07
# 343  2017-07-02   1.628663e+09  17.440446     9.338428e+07
# 344  2017-07-03   1.611146e+09  17.247060     9.341567e+07
# 345  2017-07-04   1.629516e+09  17.437723     9.344778e+07
# 346  2017-07-05   1.625689e+09  17.390919     9.347919e+07

# %%
# Rename headers
clean_crd_df = clean_crd_df.rename(
    columns={"date": "Date", "CapMrktCurUSD": "Market Cap (USD)", "PriceUSD": "Price (USD)", "number_of_coins": "Number of Coins"})
clean_crd_df.head()
# Out:
#            Date  Market Cap (USD)  Price (USD)  Number of Coins
# 342  2017-07-01      1.544252e+09    16.542040     9.335318e+07
# 343  2017-07-02      1.628663e+09    17.440446     9.338428e+07
# 344  2017-07-03      1.611146e+09    17.247060     9.341567e+07
# 345  2017-07-04      1.629516e+09    17.437723     9.344778e+07
# 346  2017-07-05      1.625689e+09    17.390919     9.347919e+07

# %%
clean_crd_df.drop(columns=['Price (USD)'])
# Out:
#             Date  Market Cap (USD)  Number of Coins
# 342   2017-07-01      1.544252e+09     9.335318e+07
# 343   2017-07-02      1.628663e+09     9.338428e+07
# 344   2017-07-03      1.611146e+09     9.341567e+07
# 345   2017-07-04      1.629516e+09     9.344778e+07
# 346   2017-07-05      1.625689e+09     9.347919e+07
# ...          ...               ...              ...
# 1194  2019-10-31      5.527997e+08     1.149158e+08
# 1195  2019-11-01      5.607901e+08     1.149425e+08
# 1196  2019-11-02      5.665300e+08     1.149691e+08
# 1197  2019-11-03      5.617707e+08     1.149957e+08
# 1198  2019-11-04      5.704847e+08     1.150217e+08
#
# [857 rows x 3 columns]

# %%
clean_crd_df.to_csv("organised_crd_df.csv")
